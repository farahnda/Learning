# %% [markdown]
# <a href="https://colab.research.google.com/github/farahnda/Learning/blob/main/BIRCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.datasets import make_blobs # BUAT DATASET PAKE BLOBS (TITIK2 DATA YG MENGELOMPOK (CLUSTER))
from sklearn.cluster import Birch

# %%
X, clusters = make_blobs(n_samples=450, centers=6, cluster_std=0.7, random_state=0)
# TOTAL DATA 450, DENGAN 6 TOTAL CLUSTERS/KELOMPOK
# nilai standar deviasi 0.7 buat atut tingkat penyebaran, makin kecil makin rapat/padat
plt.scatter(X[:, 0], X[:, 1], alpha=0.7, edgecolors='b')
# AMBIL 2 KOLOM KARNA KEBANYAKAN DEFAULT YA 2 FITUR AJA

# %%
brc = Birch(branching_factor=50, n_clusters=None, threshold=1.5)
# atur max. capacity cabang pohon = 50 node. bebasin algorithm tentuin jumlah clusters
# jarak maksimal antar titik 1.5. makin gede, makin longgar syarat penggabungannya
brc.fit(X) # BACA 450 DATA & BANGUN STRUKTUR POHON KELOMPOK DI MEMO
# Out:
# Birch(n_clusters=None, threshold=1.5)

# %%
labels = brc.predict(X) # MESIN BERI LABEL UNTUK TIAP TITIK DATA

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow', alpha=0.7, edgecolors='b')
